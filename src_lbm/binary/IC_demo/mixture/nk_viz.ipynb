# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal, scipy.optimize, scipy.integrate
import yt
# yt.set_log_level(50)
from scipy.fft import fftn

# %%
ts = yt.load('plt*')
# ds = ts[-1]

# %%
rho = np.zeros((len(ts), 32, 32, 32))
phi = np.zeros((len(ts), 32, 32, 32))

for i in range(len(ts)):
    ds = ts[i]
    ad = ds.all_data()

    rho[i] = ad[('boxlib','rho')].reshape((32, 32, 32))
    phi[i] = ad[('boxlib','phi')].reshape((32, 32, 32))
# Out:
# yt : [INFO     ] 2024-06-18 15:05:18,783 Parameters: current_time              = 0.0
# yt : [INFO     ] 2024-06-18 15:05:18,784 Parameters: domain_dimensions         = [32 32 32]
# yt : [INFO     ] 2024-06-18 15:05:18,784 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2024-06-18 15:05:18,786 Parameters: domain_right_edge         = [1. 1. 1.]

# %%
fig, axs = plt.subplots(1, 2, figsize = (6, 3))

ax = axs[0]
im = ax.imshow(rho[-1, :, 16, :])
fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.8) 
ax.set_title(r"$\rho$")

ax = axs[1]
im = ax.imshow(phi[-1, :, 16, :])
fig.colorbar(im, ax=ax, orientation='vertical', shrink = 0.8) 
ax.set_title(r"$\phi$")

fig.tight_layout()
